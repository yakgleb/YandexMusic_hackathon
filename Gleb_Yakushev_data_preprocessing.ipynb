# %% [markdown]
# # Предобработка данных

# %%
import re
import json
import pandas as pd
import numpy as np
import seaborn as sns
import spacy
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score, GridSearchCV, train_test_split
from catboost import CatBoostClassifier
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
#from polyglot.text import Text
from lightgbm import LGBMClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from scipy.stats import pointbiserialr, chi2_contingency
import fasttext

import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\Gleb\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
covers = pd.read_json('covers.json', lines=True)

# %%
meta = pd.read_json('meta.json', lines=True, convert_dates=['dttm'])

# %%
lyrics = pd.read_json('lyrics.json', lines=True)

# %% [markdown]
# Изучим наши датафреймы.

# %%
covers.head(10)
# Out:
#                   original_track_id                          track_id  \
# 0  eeb69a3cb92300456b6a5f4162093851  eeb69a3cb92300456b6a5f4162093851
# 1  fe7ee8fc1959cc7214fa21c4840dff0a  fe7ee8fc1959cc7214fa21c4840dff0a
# 2  cd89fef7ffdd490db800357f47722b20  cd89fef7ffdd490db800357f47722b20
# 3  995665640dc319973d3173a74a03860c  995665640dc319973d3173a74a03860c
# 4                              None  d6288499d0083cc34e60a077b7c4b3e1
# 5                              None  4da9d7b6d119db4d2d564a2197798380
# 6                              None  2bf283c05b601f21364d052ca0ec798d
# 7                              None  5eb13cb69b6e20dd7a42030f5936a9dc
# 8                              None  109f91266ef89cc3690079b28abfe9a3
# 9  76c538125fc5c9ec6ad1d05650a57de5  76c538125fc5c9ec6ad1d05650a57de5
#
#   track_remake_type
# 0          ORIGINAL
# 1          ORIGINAL
# 2          ORIGINAL
# 3          ORIGINAL
# 4             COVER
# 5             COVER
# 6             COVER
# 7             COVER
# 8             COVER
# 9          ORIGINAL

# %%
covers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71597 entries, 0 to 71596
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   original_track_id  4821 non-null   object
#  1   track_id           71597 non-null  object
#  2   track_remake_type  71597 non-null  object
# dtypes: object(3)
# memory usage: 1.6+ MB

# %%
covers.describe()
# Out:
#                        original_track_id                          track_id  \
# count                               4821                             71597
# unique                              4468                             71597
# top     f3e5e9db509f9b6f6d93b9c38e4e1324  eeb69a3cb92300456b6a5f4162093851
# freq                                  38                                 1
#
#        track_remake_type
# count              71597
# unique                 2
# top                COVER
# freq               67304

# %%
covers.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Посмотрим на дисбаланс классов.

# %%
covers.track_remake_type.value_counts()
# Out:
# COVER       67304
# ORIGINAL     4293
# Name: track_remake_type, dtype: int64

# %% [markdown]
# Посмотрим на кол-во записей, где original_track_id и track_id совпадают.

# %%
len(covers[covers['original_track_id'] == covers['track_id']])
# Out:
# 4293

# %% [markdown]
# Кол-во записей совпадают, перейдем к другим датасетам.

# %%
meta.head(10)
# Out:
#                            track_id                dttm  \
# 0  c3b9d6a354ca008aa4518329aaa21380 2021-12-16 21:00:00
# 1  c57e3d13bbbf5322584a7e92e6f1f7ff 2021-11-24 14:00:33
# 2  955f2aafe8717908c140bf122ba4172d 2021-11-24 15:37:03
# 3  fae5a077c9956045955dde02143bd8ff 2021-11-24 15:37:03
# 4  6bede082154d34fc18d9a6744bc95bf5 2021-11-24 15:37:03
# 5  551331ee1444de6658e71933eb7f57a2 2021-11-24 15:37:03
# 6  2be8bb01bb1aeef0908524dc11935a88 2021-11-24 15:37:03
# 7  3883d1add3ff8b60e77548a64df7c892 2021-11-24 15:37:03
# 8  59aa886979699aa7e4e2a8aed43bfe03 2021-11-24 15:37:03
# 9  2a38992b7769963937246288ad89b44c 2021-11-24 15:37:03
#
#                              title language          isrc             genres  \
# 0                   Happy New Year       EN  RUB422103970            [DANCE]
# 1                       Bad Habits       EN  QZN882178276      [ELECTRONICS]
# 2             Por Esa Loca Vanidad     None  QZNJZ2122549  [FOLK, LATINFOLK]
# 3                     Mil Lagrimas     None  QZNJZ2166033  [FOLK, LATINFOLK]
# 4              Sexo Humo y Alcohol     None  QZNJZ2122551  [FOLK, LATINFOLK]
# 5                    La Ultima Vez     None  QZNJZ2166034  [FOLK, LATINFOLK]
# 6  Homenaje a Pastor de los Santos     None  QZNJZ2122553  [FOLK, LATINFOLK]
# 7                   Los Marginales     None  QZNJZ2122554  [FOLK, LATINFOLK]
# 8                   Cuenta Conmigo     None  QZNJZ2122555  [FOLK, LATINFOLK]
# 9                   Ahora Juego Yo     None  QZNJZ2122556  [FOLK, LATINFOLK]
#
#    duration
# 0  161120.0
# 1  362260.0
# 2  260000.0
# 3  190000.0
# 4  203000.0
# 5  173000.0
# 6  192100.0
# 7  311500.0
# 8  250000.0
# 9  156000.0

# %%
meta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71769 entries, 0 to 71768
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   track_id  71768 non-null  object
#  1   dttm      71768 non-null  datetime64[ns]
#  2   title     71768 non-null  object
#  3   language  21969 non-null  object
#  4   isrc      71455 non-null  object
#  5   genres    71768 non-null  object
#  6   duration  71768 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 3.8+ MB

# %%
meta.describe(include='all')
# Out:
#                                 track_id                 dttm   title  \
# count                              71768                71768   71768
# unique                             71768                27726   45462
# top     c3b9d6a354ca008aa4518329aaa21380  2013-03-11 20:00:00  Morena
# freq                                   1                  839      81
# first                                NaN  2009-08-10 17:32:06     NaN
# last                                 NaN  2023-10-18 21:00:00     NaN
# mean                                 NaN                  NaN     NaN
# std                                  NaN                  NaN     NaN
# min                                  NaN                  NaN     NaN
# 25%                                  NaN                  NaN     NaN
# 50%                                  NaN                  NaN     NaN
# 75%                                  NaN                  NaN     NaN
# max                                  NaN                  NaN     NaN
#
#        language          isrc             genres      duration
# count     21969         71455              71768  7.176800e+04
# unique       85         71283                232           NaN
# top          EN  USTCF1018560  [FOLK, LATINFOLK]           NaN
# freq      15322             3              18391           NaN
# first       NaN           NaN                NaN           NaN
# last        NaN           NaN                NaN           NaN
# mean        NaN           NaN                NaN  2.049187e+05
# std         NaN           NaN                NaN  8.559854e+04
# min         NaN           NaN                NaN  0.000000e+00
# 25%         NaN           NaN                NaN  1.613700e+05
# 50%         NaN           NaN                NaN  1.993950e+05
# 75%         NaN           NaN                NaN  2.390700e+05
# max         NaN           NaN                NaN  5.487300e+06

# %%
meta_exploded = meta.explode("genres")
meta_exploded.duplicated().sum()
# Out:
# 0

# %%
lyrics.head(10)
# Out:
#                             lyricId  \
# 0  a951f9504e89759e9d23039b7b17ec14
# 1  0c749bc3f01eb8e6cf986fa14ccfc585
# 2  e2c8830fbc86e5964478243099eec23a
# 3  e2c8830fbc86e5964478243099eec23a
# 4  7624653ca8522ba93470843c74961b7d
# 5  7624653ca8522ba93470843c74961b7d
# 6  aaf5c8771a94127de56c08623393434a
# 7  aaf5c8771a94127de56c08623393434a
# 8  28d69bf999a2d26c5a6365b71d07a706
# 9  b6b9656527783d76fcfa0fad73625f36
#
#                                                 text  \
# 0  Живу сейчас обломами, обломками не той любви\n...
# 1  Tell me your fable\nA fable\nTell me your fabl...
# 2  You're ashamed about all your fears and doubts...
# 3  You're ashamed about all your fears and doubts...
# 4  You showed him all the best of you,\nBut I'm a...
# 5  You showed him all the best of you,\nBut I'm a...
# 6  You lost her\nAnd now you're wishing you could...
# 7  You lost her\nAnd now you're wishing you could...
# 8  If you go now\nPlease leave the light on\nJust...
# 9  Justo ayer me di cuenta\nQue solo es cuestión ...
#
#                            track_id
# 0  1c4b1230f937e4c548ff732523214dcd
# 1  0faea89b0d7d6235b5b74def72511bd8
# 2  9c6dc41d5ccd9968d07f055da5d8f741
# 3  bfd04a73e9cffdf0e282c92219a86ea1
# 4  8d70930d09cd239c948408d1317d8659
# 5  b12ecdeac6ac42e1ecac96f9f15b1159
# 6  8ef2d56d4dea12988133f6d933401733
# 7  4f41809cdbbb3d3dc99491d1273e7519
# 8  c8658fc634c181f05c882e1919e157df
# 9  682f310c802690104b3a633b6557bac2

# %%
lyrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11414 entries, 0 to 11413
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   lyricId   11414 non-null  object
#  1   text      11414 non-null  object
#  2   track_id  11414 non-null  object
# dtypes: object(3)
# memory usage: 267.6+ KB

# %%
lyrics.describe()
# Out:
#                                  lyricId  \
# count                              11414
# unique                             10915
# top     28fbafaf626c497d0d4d933b4f0d3f5b
# freq                                   9
#
#                                                      text  \
# count                                               11414
# unique                                              10644
# top     Twenty-five years and my life is still\nI'm tr...
# freq                                                   15
#
#                                 track_id
# count                              11414
# unique                             10277
# top     b891000882f4a612190142861b5c038b
# freq                                  24

# %%
lyrics.duplicated().sum()
# Out:
# 0

# %%
duplicated_track_id = lyrics[lyrics.duplicated(['track_id', 'text'])]
duplicated_track_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 264 entries, 848 to 11412
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   lyricId   264 non-null    object
#  1   text      264 non-null    object
#  2   track_id  264 non-null    object
# dtypes: object(3)
# memory usage: 8.2+ KB

# %% [markdown]
# Мы видим, что у нас много дубликатов по столбцам 'track_id' и 'text', избавимся от них.

# %%
lyrics.drop_duplicates(subset=['track_id', 'text'], inplace=True)

# %%
lyrics.describe()
# Out:
#                                  lyricId  \
# count                              11150
# unique                             10688
# top     6fe05ce48761f833737487cd7a499cd3
# freq                                   9
#
#                                                      text  \
# count                                               11150
# unique                                              10644
# top     A and X, El Orfanato\nDanza Kuduro\nLucenzo El...
# freq                                                   11
#
#                                 track_id
# count                              11150
# unique                             10277
# top     adc126c946551da4e1784e716b77992e
# freq                                  10

# %% [markdown]
# Теперь посмотрим на кол-во дубликатов по столбцу *track_id*, затем удалим и их тоже.

# %%
duplicated_track_id = lyrics[lyrics.duplicated(['track_id'])]
duplicated_track_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 873 entries, 263 to 11411
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   lyricId   873 non-null    object
#  1   text      873 non-null    object
#  2   track_id  873 non-null    object
# dtypes: object(3)
# memory usage: 27.3+ KB

# %%
lyrics.drop_duplicates(subset=['track_id'], inplace=True)

# %%
lyrics.describe()
# Out:
#                                  lyricId  \
# count                              10277
# unique                              9891
# top     6fe05ce48761f833737487cd7a499cd3
# freq                                   9
#
#                                                      text  \
# count                                               10277
# unique                                               9852
# top     A and X, El Orfanato\nDanza Kuduro\nLucenzo El...
# freq                                                    9
#
#                                 track_id
# count                              10277
# unique                             10277
# top     1c4b1230f937e4c548ff732523214dcd
# freq                                   1

# %% [markdown]
# Объединим наши таблицы.

# %%
df = meta.merge(covers, on='track_id', how='left')

# %%
df = df.merge(lyrics, on='track_id', how='left')

# %%
df.head(20)
# Out:
#                             track_id                dttm  \
# 0   c3b9d6a354ca008aa4518329aaa21380 2021-12-16 21:00:00
# 1   c57e3d13bbbf5322584a7e92e6f1f7ff 2021-11-24 14:00:33
# 2   955f2aafe8717908c140bf122ba4172d 2021-11-24 15:37:03
# 3   fae5a077c9956045955dde02143bd8ff 2021-11-24 15:37:03
# 4   6bede082154d34fc18d9a6744bc95bf5 2021-11-24 15:37:03
# 5   551331ee1444de6658e71933eb7f57a2 2021-11-24 15:37:03
# 6   2be8bb01bb1aeef0908524dc11935a88 2021-11-24 15:37:03
# 7   3883d1add3ff8b60e77548a64df7c892 2021-11-24 15:37:03
# 8   59aa886979699aa7e4e2a8aed43bfe03 2021-11-24 15:37:03
# 9   2a38992b7769963937246288ad89b44c 2021-11-24 15:37:03
# 10  530c73cb44a3b3abd7f2b299977fbb19 2021-11-24 15:37:03
# 11  c11320ee81872399e23a2670749d393a 2021-11-24 15:37:03
# 12  5f95372a5ae6e6d0d7606ea11dce1ece 2021-11-24 15:37:03
# 13  adfa176e2fb0b952569129a22d64de4d 2021-11-24 15:37:03
# 14  a7309d9c3374e12201f3226bc0fa7980 2021-11-24 15:37:21
# 15  1069db8b42f2f79b6a66ae57c6332670 2021-11-24 16:47:17
# 16  f973c844c174b9eafca7fa87560c2df9 2021-11-24 16:47:18
# 17  c996348ac49e0c243a4eb4cb0a9cfbbb 2021-11-24 16:57:06
# 18  55a4890cc667212a048ce81b4049d1ea 2021-11-24 16:59:05
# 19  f8de56ba1399dfab829176023352024d 2021-11-24 17:03:24
#
#                                                 title language          isrc  \
# 0                                      Happy New Year       EN  RUB422103970
# 1                                          Bad Habits       EN  QZN882178276
# 2                                Por Esa Loca Vanidad     None  QZNJZ2122549
# 3                                        Mil Lagrimas     None  QZNJZ2166033
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   track_id           71768 non-null  object
#  1   dttm               71768 non-null  datetime64[ns]
#  2   title              71768 non-null  object
#  3   language           21969 non-null  object
#  4   isrc               71455 non-null  object
#  5   genres             71768 non-null  object
#  6   duration           71768 non-null  float64
#  7   original_track_id  4821 non-null   object
#  8   track_remake_type  71597 non-null  object
#  9   lyricId            10277 non-null  object
#  10  text               10277 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(9)
# memory usage: 6.6+ MB

# %%
df.describe(include='all')
# Out:
#                                 track_id                 dttm   title  \
# count                              71768                71768   71768
# unique                             71768                27726   45462
# top     c3b9d6a354ca008aa4518329aaa21380  2013-03-11 20:00:00  Morena
# freq                                   1                  839      81
# first                                NaN  2009-08-10 17:32:06     NaN
# last                                 NaN  2023-10-18 21:00:00     NaN
# mean                                 NaN                  NaN     NaN
# std                                  NaN                  NaN     NaN
# min                                  NaN                  NaN     NaN
# 25%                                  NaN                  NaN     NaN
# 50%                                  NaN                  NaN     NaN
# 75%                                  NaN                  NaN     NaN
# max                                  NaN                  NaN     NaN
#
#        language          isrc             genres      duration  \
# count     21969         71455              71768  7.176800e+04
# unique       85         71283                232           NaN
# top          EN  USTCF1018560  [FOLK, LATINFOLK]           NaN
# freq      15322             3              18391           NaN
# first       NaN           NaN                NaN           NaN
# last        NaN           NaN                NaN           NaN
# mean        NaN           NaN                NaN  2.049187e+05
# std         NaN           NaN                NaN  8.559854e+04
# min         NaN           NaN                NaN  0.000000e+00
# 25%         NaN           NaN                NaN  1.613700e+05
# 50%         NaN           NaN                NaN  1.993950e+05
# 75%         NaN           NaN                NaN  2.390700e+05
# max         NaN           NaN                NaN  5.487300e+06
#
#                        original_track_id track_remake_type  \
# count                               4821             71597
# unique                              4468                 2
# top     f3e5e9db509f9b6f6d93b9c38e4e1324             COVER
# freq                                  38             67304
# first                                NaN               NaN
# last                                 NaN               NaN
# mean                                 NaN               NaN
# std                                  NaN               NaN
# min                                  NaN               NaN
# 25%                                  NaN               NaN
# 50%                                  NaN               NaN
# 75%                                  NaN               NaN
# max                                  NaN               NaN
#
#                                  lyricId  \
# count                              10277
# unique                              9891
# top     6fe05ce48761f833737487cd7a499cd3
# freq                                   9
# first                                NaN
# last                                 NaN
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
#
#                                                      text
# count                                               10277
# unique                                               9852
# top     A and X, El Orfanato\nDanza Kuduro\nLucenzo El...
# freq                                                    9
# first                                                 NaN
# last                                                  NaN
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %% [markdown]
# Удалим пропуски в столбце isrc.

# %%
df.dropna(subset=['isrc'], inplace=True)

# %% [markdown]
# Посмотрим на баланс классов еще раз.

# %%
df.track_remake_type.value_counts()
# Out:
# COVER       67083
# ORIGINAL     4204
# Name: track_remake_type, dtype: int64

# %%
len(df.loc[df['track_id'] == df['original_track_id']])
# Out:
# 4204

# %% [markdown]
# Создадим новый признак - год появения трека в базе isrc. Напишем функцию, которая будет возвращать нам год из 6-го и 7-го символов isrc-кода.

# %%
def convert(x):
    try:
        return '19' + x[5:7] if int(x[5:7]) > 23 else '20' + x[5:7]
    except ValueError:
        return None

# %%
df['year'] = df['isrc'].apply(convert)

# %%
# 29576       EN  QZK6J2199150              [POP]  212340.0
# 29880       EN  TCAFN2139316              [RAP]  193200.0
# 31763       EN  QZNMX2159217              [RAP]  204750.0
# 35877       EN  QZNWR2184951              [RAP]  144840.0
# 36750       DE  QZNWT2154869              [RAP]  169560.0
# 38096       EN  QZNWV2173223              [RAP]  145210.0
# 38488     None  QZSR42100709            [DANCE]  123740.0
# 44887       EN  USSM19909073              [POP]  257060.0
# 50245     None  USCGJ1199593  [FOREIGNRAP, RAP]  158690.0
# 50301     None  GBQ3B1100907            [DANCE]  256050.0
# 52588       EN  FR59R1728692    [FOLK, AFRICAN]  220960.0
# 52739     None  TCADC1787635              [RAP]  162250.0
# 55834     None  UKXN21948919             [FOLK]  208350.0
# 56745       EN  QMGR32122918              [RAP]  180000.0
# 59197       DA  DKADG2001089              [RAP]  208960.0
# 61084       EN  QZNMU2141775              [RAP]  172560.0
# 62044       DE  NL4NL2113172              [RAP]  190090.0
# 62538       DE  DETV91501632              [RAP]  141940.0
# 62773     None  GBMA22147766              [RAP]  164250.0
# 64290       EN  QZQ4X2100013             [FOLK]  213710.0
# 65497       EN  UST8K1728073              [RAP]  172030.0
# 65874       FR  CH6542131792              [RAP]  152460.0
# 67007     None  AEA0D1866274              [RAP]  158090.0
# 67216     None  TCADY1800958              [RAP]  181370.0
# 67394     None  QMEZE1870777              [RAP]  170890.0
# 68017     None  BGA471405023            [DANCE]  313440.0
#
#                       original_track_id track_remake_type  \
# 2727   ecb6d083492582beb335a82473416c16          ORIGINAL
# 2945   bc14fcffe5e8f9f4e6d7aedf8778e001          ORIGINAL
# 7129   347a1dbfa9d4146b098a537926c8c9bb          ORIGINAL
# 8931   0af163b20807c7559c4ce168d5bf194d          ORIGINAL
# 9059   dfdeea64f0e60e66cba2ce7f7043ab45          ORIGINAL
# 9780   438dc9c22a6a34ea7af369fd95983dbb          ORIGINAL
# 13456  a86e987df0929f1d898f7b960fce8df9          ORIGINAL
# 16758  7ece1d8f67b3d164f188c970d2144be6          ORIGINAL
# 17674  225404f4a0f6b181a915bc030d1d477a          ORIGINAL
# 17894  eb4af6e78bb0b0729af9d66c110c439c          ORIGINAL
# 18123  2420d6c727a320065e800ab326f1270a          ORIGINAL
# 18144  1b48e619c862fa230fb395275f20aed1          ORIGINAL
# 18516  846c29cbc98b0376c616175b26eefa00          ORIGINAL
# 18749  8a097e9001b3a211a764a04361125e13          ORIGINAL
# 20908  c4e2ed038fe899f90d8b5686a4ba9bd4          ORIGINAL
# 21880  5b5abd9535c2fdf4709fd082581d62d7          ORIGINAL
# 21898  90b8c652d754bc3f2c31fe1453b83669          ORIGINAL
# 22484  efb882c45c857901daa5b369592bf6e6          ORIGINAL
# 22984  4b917b8319ff7e6e7ebf96da165cd1f8          ORIGINAL
# 24219  2424960a488b004dbd23cb1118d810be          ORIGINAL
# 28415  a14439640ed708d7576a0979b906637f          ORIGINAL
# 29576  6b065a6aba4d6c502e6dd8bf7e5835c6          ORIGINAL
# 29880  480e5273337e103287751290cd4e91a9          ORIGINAL
# 31763  d469651ac9c62ffec1d5bfa2a3bb1057          ORIGINAL
# 35877  70a0709caf76eec7f537067906c07761          ORIGINAL
# 36750  38a59651a168c0116b4af40a076422b2          ORIGINAL
# 38096  4f3d8d2fe1df424bb9e961f4a1d0337f          ORIGINAL
# 38488  f1d5a297ab198526232dfd52266bc454          ORIGINAL
# 44887  9050384cce6c221c39d6e25d02561612          ORIGINAL
# 50245  ee9a0cf0b378593a5fc571887c36089f          ORIGINAL
# 50301  5696cdea90057bf89e36cb8bc3132c2a          ORIGINAL
# 52588  942afdeaf7b3cf6dc1422bd589028d79          ORIGINAL
# 52739  f56f36b4f84a74895094ec8f1ef0e201          ORIGINAL
# 55834  c11d0e84142127a06a1e55b6663f3cd1          ORIGINAL
# 56745  e1c18ca3d92dcf873d3d5dd6204c5bb2          ORIGINAL
# 59197  45d34eef11667ac33492d04aa0bea406          ORIGINAL
# 61084  458c63572ae3b0879c2b24fb61229bb3          ORIGINAL
# 62044  3a6f69444e920381c35eae28577625c9          ORIGINAL
# 62538  78f051cf4372ae401cbe7147bb3ed43a          ORIGINAL
# 62773  e94d1c078d5a78b86b2fd47d70c9a09e          ORIGINAL
# 64290  9696a8d279e70f891a28625636e9bb2b          ORIGINAL
# 65497  9cfb533ddf4869a3ea5a7057cca285a4          ORIGINAL
# 65874  69172ad837eb546f1b7c4d505e4fc2ad          ORIGINAL
# 67007  7283b1f443aef8e034a714ad776b6340          ORIGINAL
# 67216  c2e8a9d46a97f1e7c78603f5b277f5f1          ORIGINAL
# 67394  82407db40436c54fe14d0730307e2556          ORIGINAL
# 68017  bb8d21c1e0cf0d4c06072669c4300289          ORIGINAL
#
#                                 lyricId  \
# 2727                                NaN
# 2945   c21e223482499b573d5c24d78c82ff1a
# 7129                                NaN
# 8931                                NaN
# 9059                                NaN
# 9780                                NaN
# 13456                               NaN
# 16758  0a06fb0741691c03d111032e84f1498c
# 17674                               NaN
# 17894                               NaN
# 18123  b5500400cbb3f23eb8443f74250dcb77
# 18144                               NaN
# 18516  b5ae6b47a79aeda6a51352428ab9917b
# 18749                               NaN
# 20908                               NaN
# 21880                               NaN
# 21898                               NaN
# 22484                               NaN
# 22984                               NaN
# 24219                               NaN
# 28415                               NaN
# 29576                               NaN
# 29880                               NaN
# 31763                               NaN
# 35877                               NaN
# 36750                               NaN
# 38096                               NaN
# 38488                               NaN
# 44887  bccbdb3c1121adb959b1b36430c93f4a
# 50245                               NaN
# 50301                               NaN
# 52588  91eb46a5cbc47001d9482064cce3a706
# 52739                               NaN
# 55834                               NaN
# 56745                               NaN
# 59197  0335302abb721b06084569ab42d9c804
# 61084                               NaN
# 62044                               NaN
# 62538                               NaN
# 62773  89d948d4e1160e3b7e655820da7bbf26
# 64290  fd7b735c7892f5c25e69cd295c1bd087
# 65497                               NaN
# 65874                               NaN
# 67007                               NaN
# 67216                               NaN
# 67394                               NaN
# 68017                               NaN
#
#                                                     text  year
# 2727                                                 NaN  2022
# 2945   No, no, no, whoah\nMmmmm, no, no, no\nWhoah\n\...  2022
# 7129                                                 NaN  2019
# 8931                                                 NaN  2022
# 9059                                                 NaN  2022
# 9780                                                 NaN  2022
# 13456                                                NaN  2022
# 16758  As he came into the window\nIt was the sound o...  2019
# 17674                                                NaN  2020
# 17894                                                NaN  2020
# 18123  Rah, it's BKay you know\nYo Itchy, is that how...  2020
# 18144                                                NaN  2020
# 18516  Baby walked in like a criminal\n(Yeah yeah)\nS...  2020
# 18749                                                NaN  2020
# 20908                                                NaN  2021
# 21880                                                NaN  2021
# 21898                                                NaN  2021
# 22484                                                NaN  2021
# 22984                                                NaN  2021
# 24219                                                NaN  2021
# 28415                                                NaN  2021
# 29576                                                NaN  2021
# 29880                                                NaN  2021
# 31763                                                NaN  2021
# 35877                                                NaN  2021
# 36750                                                NaN  2021
# 38096                                                NaN  2021
# 38488                                                NaN  2021
# 44887  As he came into the window\nIt was the sound o...  1999
# 50245                                                NaN  2011
# 50301                                                NaN  2011
# 52588  Tse-yeezy\nKill them\n\nAh music wey dey reson...  2017
# 52739                                                NaN  2017
# 55834                                                NaN  2019
# 56745                                                NaN  2021
# 59197  Et helt kilo på sædet, et halvt kilo om halsen...  2020
# 61084                                                NaN  2021
# 62044                                                NaN  2021
# 62538                                                NaN  2015
# 62773  As he came into the window\nWas the sound of a...  2021
# 64290  Oh way oh way ahh\nOh way ah way oh way\nOh wa...  2021
# 65497                                                NaN  2017
# 65874                                                NaN  2021
# 67007                                                NaN  2018
# 67216                                                NaN  2018
# 67394                                                NaN  2018
# 68017                                                NaN  2014

# %% [markdown]
# Я считаю это выбросами и предлагаю их переметить, выбрав самый ранний трек как оригинал, остальные отметим как 'COVER'.

# %%
# Сначала создаем копию DataFrame, чтобы избежать изменения исходных данных
df_copy = df.copy()

# %%
df_copy.reset_index(drop=True, inplace=True)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71454 entries, 0 to 71453
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   track_id           71454 non-null  object
#  1   dttm               71454 non-null  datetime64[ns]
#  2   title              71454 non-null  object
#  3   language           21964 non-null  object
#  4   isrc               71454 non-null  object
#  5   genres             71454 non-null  object
#  6   duration           71454 non-null  float64
#  7   original_track_id  4728 non-null   object
#  8   track_remake_type  71286 non-null  object
#  9   lyricId            10214 non-null  object
#  10  text               10214 non-null  object
#  11  year               71454 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(10)
# memory usage: 6.5+ MB

# %%
# Приводим все названия треков к нижнему регистру
df_copy['title'] = df_copy['title'].str.lower()

# Удаляем все знаки препинания и символы
df_copy['title'] = df_copy['title'].apply(lambda x: re.sub(r'[^\w\s]', '', x))

# %%
df_copy.title.value_counts()
# Out:
# smooth criminal         84
# morena                  81
# rolê                    72
# wicked game             68
# esquema preferido       66
#                         ..
# i wanna love you         1
# moving mountains         1
# chill with you           1
# you exist in my song     1
# 17                       1
# Name: title, Length: 43281, dtype: int64

# %%
# Отбираем группы треков, где 'ORIGINAL' встречается больше 1 раза
groups_orig = df_copy[df_copy['track_remake_type'] == 'ORIGINAL'].groupby('title').filter(lambda x: len(x) > 1)

# %%
groups_orig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 749 entries, 152 to 71437
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   track_id           749 non-null    object
#  1   dttm               749 non-null    datetime64[ns]
#  2   title              749 non-null    object
#  3   language           427 non-null    object
#  4   isrc               749 non-null    object
#  5   genres             749 non-null    object
#  6   duration           749 non-null    float64
#  7   original_track_id  749 non-null    object
#  8   track_remake_type  749 non-null    object
#  9   lyricId            428 non-null    object
#  10  text               428 non-null    object
#  11  year               749 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(10)
# memory usage: 76.1+ KB

# %%
# Для каждой группы отмечаем самый ранний трек как 'ORIGINAL', а остальные помечаем как 'COVER'
for name, group in groups_orig.groupby('title'):
    idx_min = group['year'].min()
    df_copy.loc[(df_copy['title'] == name) & (df_copy['year'] != idx_min), 'track_remake_type'] = 'COVER'
    df_copy.loc[(df_copy['title'] == name) & (df_copy['year'] == idx_min), 'track_remake_type'] = 'ORIGINAL'

# %%
# Снова проверим группы треков, где 'ORIGINAL' встречается больше 1 раза
groups_orig = df_copy[df_copy['track_remake_type'] == 'ORIGINAL'].groupby('title').filter(lambda x: len(x) > 1)

groups_orig.title.value_counts()
# Out:
# bagatelle no 25 in a minor woo 59 für elise    15
# home                                           12
# lonely                                         11
# bright lights                                   6
# blue lines                                      5
#                                                ..
# dont need your love                             2
# deep                                            2
# ocean eyes                                      2
# ok                                              2
# привет                                          2
# Name: title, Length: 111, dtype: int64

# %% [markdown]
# У нас остались такие треки, видимо, они были выпущены в одном году и имеют одно название, просто выпускались на разных релизах, оставим как есть. Снова проверим баланс классов.

# %% [markdown]
# Теперь повторим для групп треков, размеченных как COVER.

# %%
# Отбираем группы треков, где все треки размечены как 'COVER' и встречаются больше 1 раза
groups_cover = df_copy[df_copy['track_remake_type'] == 'COVER'].groupby('title').filter(lambda x: len(x) > 1)

# Для каждой группы отмечаем самый ранний трек как 'ORIGINAL', а остальные помечаем как 'COVER'
for name, group in groups_cover.groupby('title'):
    idx_min = group['year'].min()
    df_copy.loc[(df['title'] == name) & (df_copy['year'] != idx_min), 'track_remake_type'] = 'COVER'
    df_copy.loc[(df['title'] == name) & (df_copy['year'] == idx_min), 'track_remake_type'] = 'ORIGINAL'

# %%
df_copy.track_remake_type.value_counts()
# Out:
# COVER       67275
# ORIGINAL     4014
# Name: track_remake_type, dtype: int64

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71454 entries, 0 to 71453
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  71454 non-null  object
#  1   dttm                      71454 non-null  datetime64[ns]
#  2   title                     71454 non-null  object
#  3   language                  21964 non-null  object
#  4   isrc                      71454 non-null  object
#  5   genres                    71454 non-null  object
#  6   duration                  71454 non-null  float64
#  7   original_track_id         4728 non-null   object
#  8   track_remake_type         71289 non-null  object
#  9   lyricId                   10214 non-null  object
#  10  text                      10214 non-null  object
#  11  year                      71454 non-null  object
#  12  track_remake_type_binary  71289 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(10)
# memory usage: 7.1+ MB

# %% [markdown]
# У нас образовались пропуски в track_remake_type, удалим их.

# %%
df_copy.dropna(subset=['track_remake_type'], inplace=True)

# %% [markdown]
# Поскольку мы планируем решать задачу бинарной классификации (модель должна определить, кавер перед ней или нет), то переведем значения столбца track_remake_type в бинарную систему, где ORIGINAL будет 1, а COVER будет 0.

# %%
# Создаем словарь для преобразования
remake_type_dict = {'ORIGINAL': 1, 'COVER': 0}

# Применяем словарь к столбцу 'track_remake_type'
df_copy['track_remake_type_binary'] = df_copy['track_remake_type'].map(remake_type_dict)

# %%
df_copy['track_remake_type_binary'] = df_copy['track_remake_type_binary'].astype('int')

# %%
df_copy.head()
# Out:
#                            track_id                dttm                 title  \
# 0  c3b9d6a354ca008aa4518329aaa21380 2021-12-16 21:00:00        happy new year
# 1  c57e3d13bbbf5322584a7e92e6f1f7ff 2021-11-24 14:00:33            bad habits
# 2  955f2aafe8717908c140bf122ba4172d 2021-11-24 15:37:03  por esa loca vanidad
# 3  fae5a077c9956045955dde02143bd8ff 2021-11-24 15:37:03          mil lagrimas
# 4  6bede082154d34fc18d9a6744bc95bf5 2021-11-24 15:37:03   sexo humo y alcohol
#
#   language          isrc             genres  duration original_track_id  \
# 0       EN  RUB422103970            [DANCE]  161120.0              None
# 1       EN  QZN882178276      [ELECTRONICS]  362260.0              None
# 2     None  QZNJZ2122549  [FOLK, LATINFOLK]  260000.0              None
# 3     None  QZNJZ2166033  [FOLK, LATINFOLK]  190000.0              None
# 4     None  QZNJZ2122551  [FOLK, LATINFOLK]  203000.0              None
#
#   track_remake_type                           lyricId  \
# 0             COVER  36777cce0740d1e3d37a5a221c71d859
# 1             COVER  8284927611c6a6fc49ff1ce7b3a88314
# 2             COVER                               NaN
# 3             COVER                               NaN
# 4             COVER                               NaN
#
#                                                 text  year  \
# 0  No more champagne\nAnd the fireworks are throu...  2021
# 1  Ooh-ooh, ooh, ooh\n\nEvery time you come aroun...  2021
# 2                                                NaN  2021
# 3                                                NaN  2021
# 4                                                NaN  2021
#
#    track_remake_type_binary
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71289 entries, 0 to 71453
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  71289 non-null  object
#  1   dttm                      71289 non-null  datetime64[ns]
#  2   title                     71289 non-null  object
#  3   language                  21824 non-null  object
#  4   isrc                      71289 non-null  object
#  5   genres                    71289 non-null  object
#  6   duration                  71289 non-null  float64
#  7   original_track_id         4728 non-null   object
#  8   track_remake_type         71289 non-null  object
#  9   lyricId                   10065 non-null  object
#  10  text                      10065 non-null  object
#  11  year                      71289 non-null  object
#  12  track_remake_type_binary  71289 non-null  int32
# dtypes: datetime64[ns](1), float64(1), int32(1), object(10)
# memory usage: 7.3+ MB

# %%
df_copy.track_remake_type_binary.value_counts()
# Out:
# 0    67275
# 1     4014
# Name: track_remake_type_binary, dtype: int64

# %% [markdown]
# # Обучение модели

# %%
#Замена пропущенных значений на пустые строки
#df_copy['text'].fillna('', inplace=True)

model = SentenceTransformer('LaBSE')

# Применяем модель к столбцам 'title' и 'text'
df_copy['title_vector'] = df_copy['title'].apply(model.encode)
#df_copy['text_vector'] = df_copy['text'].apply(model.encode)
